# %% [markdown]
# # Block 7 Refresh Check - Titanic Hypothesis And Evidence
#
# Time cap: 45 minutes. Stop when the timer ends; incomplete is acceptable, skipped is not.
#
# This refresh check uses `titanic.csv` to test whether the Block 7 moves transfer to a different dataset.
#
# No worked examples. No teaching cells. Questions only.
#
# **Refresh dataset:** Titanic CSV
# **Dataset file:** `titanic.csv`, supplied in the `datasets` folder with these materials.
#
# If you keep the supplied folder layout, use `../../datasets/titanic.csv`. If you move the files, point the path to your own copy.

# %% [markdown]
# ## Setup
#
# Import pandas as `pd`, import `stats` from SciPy, store the relative Titanic path in `dataset_path`, and load the table into `df`.
#
# **Your answer cell is directly below.**

# %% [markdown]
# ## Check 1 - Hypothesis First
#
# State a null hypothesis and an alternative hypothesis for this question before any test is run:
#
# Did passengers who survived pay a higher average `Fare` than passengers who did not survive?
#
# **Your written answer cell is directly below.**

# %% [markdown]
# ## Check 2 - Split The Groups
#
# Split the Titanic data into two groups: passengers who survived and passengers who did not. Then calculate and print the mean `Fare` for each group.
#
# **Your answer cell is directly below.**

# %% [markdown]
# ## Check 3 - Run The t-test
#
# Run a t-test comparing `Fare` between survivors and non-survivors. Print the t-statistic and the p-value.
#
# **Your answer cell is directly below.**

# %% [markdown]
# ## Check 4 - Statistical Significance
#
# In one sentence, state whether the result is statistically significant.
#
# **Your answer cell is directly below.**

# %% [markdown]
# ## Check 5 - Practical Importance
#
# In one sentence, state whether statistical significance here implies practical importance.
#
# **Your answer cell is directly below.**

# %% [markdown]
# ## Plain-English Findings
#
# Write three plain-English observations about what the Titanic fare data showed.
#
# 1.
# 2.
# 3.
