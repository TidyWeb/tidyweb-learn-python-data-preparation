# %% [markdown]
# # Block 10 - Dashboard And Presentation
#
# **Lesson dataset:** Superstore Sales CSV
# **Dataset file:** `superstore_sales.csv`, supplied in the `datasets` folder with these materials.
#
# When you run this notebook on your own machine, set the path to wherever your copy of `superstore_sales.csv` is saved. If you keep the supplied folder layout, use `../../datasets/superstore_sales.csv`.

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../../datasets/superstore_sales.csv')

# %% [markdown]
# ## Block 10 - Dashboard and Presentation
#
# This is the final block.
#
# Your task:
# - Choose three KPIs from this dataset
# - Produce one chart per KPI
# - Write a plain-English findings report answering four questions
# - Prepare a verbal summary and deliver it aloud
#
# A KPI is a number that measures something specific for a stated reason.
# Not every column is a KPI. Choose three that tell three different stories.
#
# Columns available: Sales, Profit, Quantity, Discount, Category, Sub-Category, Segment, Region, Ship Mode

# %% [markdown]
# ## KPI Selection
#
# Before writing any code, state your three KPIs here.
#
# For each one, complete this sentence in plain English:
#
# KPI 1: I am measuring ___ because ___
#
# KPI 2: I am measuring ___ because ___
#
# KPI 3: I am measuring ___ because ___
#
# Rules:
# - Each KPI must answer a different question
# - At least one must involve a comparison between categories or segments
# - At least one must reveal something not obvious from scanning the raw table

# %% [markdown]
# ## KPI 1
#
# State your KPI in one sentence above the code cell.
# Produce one chart that shows it clearly.
# Below the chart, write one sentence stating what the chart shows
# and one sentence stating what the chart cannot tell you.

# %% [markdown]
# ## KPI 2
#
# State your KPI in one sentence above the code cell.
# Produce one chart that shows it clearly.
# Below the chart, write one sentence stating what the chart shows
# and one sentence stating what the chart cannot tell you.

# %% [markdown]
# ## KPI 3
#
# State your KPI in one sentence above the code cell.
# Produce one chart that shows it clearly.
# Below the chart, write one sentence stating what the chart shows
# and one sentence stating what the chart cannot tell you.

# %% [markdown]
# ## Findings Report
#
# Answer each question in plain English.
# Every observation must be traceable to something visible in the data.
# Vague findings do not count.
#
# **What does each KPI show?**
# Write one sentence per KPI.
#
# KPI 1 finding:
#
# KPI 2 finding:
#
# KPI 3 finding:
#
# **What does each KPI not show?**
# Write one sentence per KPI on what the chart cannot confirm or what context is missing.
#
# KPI 1 limit:
#
# KPI 2 limit:
#
# KPI 3 limit:
#
# **What would you check next?**
# Write one specific follow-up question per KPI. Name the column and the move you would use.
#
# KPI 1 next:
#
# KPI 2 next:
#
# KPI 3 next:
#
# **What can the data not tell you?**
# Write one honest overall limitation of this dataset for the purpose you used it.

# %% [markdown]
# ## Verbal Summary
#
# Prepare your verbal summary using this structure.
# Write it out fully first. Then put it aside and deliver it in your own words.
#
# Opening statement - what the dataset is and what you were trying to understand. One sentence.
#
# KPI 1 summary - what it shows. One sentence.
#
# KPI 2 summary - what it shows. One sentence.
#
# KPI 3 summary - what it shows. One sentence.
#
# Overall conclusion - what the three KPIs together suggest. One sentence.
#
# Honest limitation - what the data cannot confirm. One sentence.
#
# Six sentences. Prepare them. Do not read them. Deliver them.
