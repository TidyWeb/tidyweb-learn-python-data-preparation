# %% [markdown]
# # Block 1 Refresh Check - Seattle Weather
#
# Time cap: 45 minutes.
#
# This is a short refresher of Block 1, not a taught walkthrough.
#
# **Refresh dataset:** Seattle Weather CSV
# **Dataset file:** `seattle_weather.csv`, supplied in the `datasets` folder with these materials.
#
# When you run this notebook on your own machine, set the path to wherever your copy of `seattle_weather.csv` is saved. If you keep the supplied folder layout, use `../../datasets/seattle_weather.csv`.
#
# Use this notebook to check whether the Block 1 table-reading moves transfer to a different dataset.
#
# No worked examples appear in this notebook. Every code cell is for your own answer.

# %% [markdown]
# ## Check 1 - Setup
#
# Import pandas as `pd`, store the Seattle Weather file path in `dataset_path`, and load the CSV into `df`.
#
# <div style="border:2px solid #b45309; border-left:8px solid #b45309; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Your answer cell is directly below.</strong><br>
# This refresh check has no worked examples. Type your answer in the empty code cell under this orange box.
# </div>

# %% [markdown]
# ## Check 2 - First Look
#
# Show the first five rows of `df` with `df.head()`.
#
# <div style="border:2px solid #b45309; border-left:8px solid #b45309; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Your answer cell is directly below.</strong><br>
# This refresh check has no worked examples. Type your answer in the empty code cell under this orange box.
# </div>

# %% [markdown]
# ## Check 3 - Table Size
#
# Show the shape of `df` with `df.shape`.
#
# <div style="border:2px solid #b45309; border-left:8px solid #b45309; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Your answer cell is directly below.</strong><br>
# This refresh check has no worked examples. Type your answer in the empty code cell under this orange box.
# </div>

# %% [markdown]
# ## Check 4 - Structure Report
#
# Show the structure report for `df` with `df.info()`.
#
# <div style="border:2px solid #b45309; border-left:8px solid #b45309; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Your answer cell is directly below.</strong><br>
# This refresh check has no worked examples. Type your answer in the empty code cell under this orange box.
# </div>

# %% [markdown]
# ## Check 5 - Full Summary
#
# Show summary information for every column in `df` with `df.describe(include="all")`.
#
# <div style="border:2px solid #b45309; border-left:8px solid #b45309; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Your answer cell is directly below.</strong><br>
# This refresh check has no worked examples. Type your answer in the empty code cell under this orange box.
# </div>

# %% [markdown]
# ## Check 6 - Column Types
#
# Show the data type of every column in `df` with `df.dtypes`.
#
# <div style="border:2px solid #b45309; border-left:8px solid #b45309; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Your answer cell is directly below.</strong><br>
# This refresh check has no worked examples. Type your answer in the empty code cell under this orange box.
# </div>

# %% [markdown]
# ## Check 7 - One Column
#
# Select the `weather` column from `df`.
#
# <div style="border:2px solid #b45309; border-left:8px solid #b45309; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Your answer cell is directly below.</strong><br>
# This refresh check has no worked examples. Type your answer in the empty code cell under this orange box.
# </div>

# %% [markdown]
# ## Check 8 - Two Columns
#
# Select the `date` and `temp_max` columns together from `df`.
#
# <div style="border:2px solid #b45309; border-left:8px solid #b45309; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Your answer cell is directly below.</strong><br>
# This refresh check has no worked examples. Type your answer in the empty code cell under this orange box.
# </div>

# %% [markdown]
# ## Check 9 - Value Counts
#
# Count the values in the `weather` column with `.value_counts()`.
#
# <div style="border:2px solid #b45309; border-left:8px solid #b45309; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Your answer cell is directly below.</strong><br>
# This refresh check has no worked examples. Type your answer in the empty code cell under this orange box.
# </div>

# %% [markdown]
# ## Plain-English Findings
#
# Write three observations about what the Seattle Weather data showed.
#
# 1.
# 2.
# 3.
#
# Write one thing you would check next if this were a real analysis task.
#
# -
