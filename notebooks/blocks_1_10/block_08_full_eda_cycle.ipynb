# %% [markdown]
# # Block 8 - Full EDA Cycle
#
# This is a performance block. There are no worked examples, no hints, and no scaffolding.
# Load the dataset, run a full exploratory data analysis, and write a plain-English findings note answering four specific questions.
#
# The notebook cells are scratch space. They do not need to be clean or linear.
# The findings note is the deliverable.
#
# **Dataset:** `titanic.csv`
# **Path:** `/home/Phil/C&C/Learn_Python_Data/datasets/titanic.csv`

# %% [markdown]
# ## Setup
#
# Run these cells first.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/home/Phil/C&C/Learn_Python_Data/datasets/titanic.csv')

# %% [markdown]
# ## Completion Standard
#
# The EDA is complete when all of the following have been done:
#
# - the dataset shape, column types, and missingness have been checked
# - at least one filtering question has been asked and answered
# - at least one grouping or sorting question has been asked and answered
# - at least one chart has been produced and described in one plain-English sentence
# - the four findings questions have been answered in writing

# %% [markdown]
# ## Your EDA
#
# Work below this cell. Use as many cells as you need.
# No structure is imposed. No order is required.

# %% [markdown]
# ## Findings Note
#
# Answer each of the four questions below in plain English.
# Every observation must be traceable to something visible in the data.
# Vague findings do not count.
#
# **Question 1 - What does this data contain?**
# Write here: shape, column names, data types, and what each column appears to represent.
#
# **Question 2 - What stands out?**
# Write here: unusual values, missingness, category imbalance, skew, relationships, or anything that would prompt a follow-up question.
#
# **Question 3 - What would you check next?**
# Write here: specific further questions the data raises. Name the columns and the move you would use.
#
# **Question 4 - What can you not conclude from this data alone?**
# Write here: honest limits. What the dataset cannot confirm, what context is missing, and what assumptions would be needed to go further.
