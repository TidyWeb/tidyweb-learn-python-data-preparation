# %% [markdown]
# # Block 5 Refresh Check - Superstore Visualisation
#
# Time cap: 45 minutes.
#
# This is a short refresher, not a taught walkthrough.
#
# **Refresh dataset:** Superstore Sales CSV
# **Dataset file:** `superstore_sales.csv`, supplied in the `datasets` folder with these materials.
#
# When you run this notebook on your own machine, set the path to wherever your copy of `superstore_sales.csv` is saved. If you keep the supplied folder layout, use `../../datasets/superstore_sales.csv`.

# %% [markdown]
# ## Check 1 - Setup
#
# Import pandas as `pd`, import `matplotlib.pyplot as plt`, store the Superstore Sales file path in `dataset_path`, and load the CSV into `df`.
#
# <div style="border:2px solid #b45309; border-left:8px solid #b45309; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Your answer cell is directly below.</strong><br>
# This orange-marked step is for your own answer. No worked example is provided in a refresh check.
# </div>

# %% [markdown]
# ## Check 2 - Bar Chart
#
# Create a bar chart showing how often each `Category` value appears.
#
# <div style="border:2px solid #b45309; border-left:8px solid #b45309; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Your answer cell is directly below.</strong><br>
# This orange-marked step is for your own answer. No worked example is provided in a refresh check.
# </div>

# %% [markdown]
# ## Check 3 - Histogram
#
# Create a histogram of the `Sales` column.
#
# <div style="border:2px solid #b45309; border-left:8px solid #b45309; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Your answer cell is directly below.</strong><br>
# This orange-marked step is for your own answer. No worked example is provided in a refresh check.
# </div>

# %% [markdown]
# ## Check 4 - Scatter Plot
#
# Create a scatter plot with `Discount` on the x axis and `Profit` on the y axis.
#
# <div style="border:2px solid #b45309; border-left:8px solid #b45309; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Your answer cell is directly below.</strong><br>
# This orange-marked step is for your own answer. No worked example is provided in a refresh check.
# </div>

# %% [markdown]
# ## Check 5 - Chart Choice Rule
#
# For the question "How often does each `Region` value appear?", write your answer as a quoted sentence choosing `bar chart`, `histogram`, or `scatter plot`, and say why.
#
# <div style="border:2px solid #b45309; border-left:8px solid #b45309; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Your answer cell is directly below.</strong><br>
# This orange-marked step is for your own answer. No worked example is provided in a refresh check.
# </div>

# %% [markdown]
# ## Check 6 - What A Chart Shows And Cannot Show
#
# Write two quoted sentences about your scatter plot: one saying what it shows, and one saying what it cannot show on its own.
#
# <div style="border:2px solid #b45309; border-left:8px solid #b45309; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Your answer cell is directly below.</strong><br>
# This orange-marked step is for your own answer. No worked example is provided in a refresh check.
# </div>

# %% [markdown]
# ## Plain-English Findings
#
# Write three observations about what your Superstore charts showed.
#
# 1.
# 2.
# 3.
#
# Write one thing you would check next if this were a real analysis task.
#
# -
#
# <div style="border:2px solid #b45309; border-left:8px solid #b45309; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Your answer cell is directly below.</strong><br>
# This orange-marked step is for your own answer. No worked example is provided in a refresh check.
# </div>
