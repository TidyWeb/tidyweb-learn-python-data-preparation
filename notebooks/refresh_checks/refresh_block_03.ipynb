# %% [markdown]
# # Block 3 Refresh Check - Titanic Missing Data
#
# Time cap: 45 minutes.
#
# This is a short refresher of Block 3, not a taught walkthrough.
#
# **Refresh dataset:** Titanic CSV
# **Dataset file:** `titanic.csv`, supplied in the `datasets` folder with these materials.
#
# When you run this notebook on your own machine, set the path to wherever your copy of `titanic.csv` is saved. If you keep the supplied folder layout, use `../../datasets/titanic.csv`.
#
# Use this notebook to check whether the Block 3 missing-data and cleaning moves transfer to a different dataset.
#
# No worked examples appear in this notebook. Every code cell is for your own answer.

# %% [markdown]
# ## Check 1 - Setup
#
# Import pandas as `pd`, store the Titanic file path in `dataset_path`, and load the CSV into `df`.
#
# <div style="border:2px solid #b45309; border-left:8px solid #b45309; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Your answer cell is directly below.</strong><br>
# This refresh check has no worked examples. Type your answer in the empty code cell under this orange box.
# </div>

# %% [markdown]
# ## Check 2 - Find Missing Cells
#
# Use `df.isnull()` to show which cells in the Titanic table are missing.
#
# <div style="border:2px solid #b45309; border-left:8px solid #b45309; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Your answer cell is directly below.</strong><br>
# This refresh check has no worked examples. Type your answer in the empty code cell under this orange box.
# </div>

# %% [markdown]
# ## Check 3 - Count Missing Values
#
# Use `df.isnull().sum()` to count the missing values in each column.
#
# <div style="border:2px solid #b45309; border-left:8px solid #b45309; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Your answer cell is directly below.</strong><br>
# This refresh check has no worked examples. Type your answer in the empty code cell under this orange box.
# </div>

# %% [markdown]
# ## Check 4 - Make A Safe Copy
#
# Make a safe working copy called `df_clean`, then display `df_clean` to confirm the copy exists.
#
# <div style="border:2px solid #b45309; border-left:8px solid #b45309; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Your answer cell is directly below.</strong><br>
# This refresh check has no worked examples. Type your answer in the empty code cell under this orange box.
# </div>

# %% [markdown]
# ## Check 5 - Drop Rows With Any Missing Value
#
# Start with `df_clean = df.copy()`. Then use `df_clean.dropna()` to show the rows that remain after removing any row with a missing value.
#
# <div style="border:2px solid #b45309; border-left:8px solid #b45309; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Your answer cell is directly below.</strong><br>
# This refresh check has no worked examples. Type your answer in the empty code cell under this orange box.
# </div>

# %% [markdown]
# ## Check 6 - Drop Rows Missing One Column
#
# Start with `df_clean = df.copy()`. Then use `df_clean.dropna(subset=["Embarked"])` to remove only the rows where `Embarked` is missing.
#
# <div style="border:2px solid #b45309; border-left:8px solid #b45309; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Your answer cell is directly below.</strong><br>
# This refresh check has no worked examples. Type your answer in the empty code cell under this orange box.
# </div>

# %% [markdown]
# ## Check 7 - Fill One Text Column
#
# Start with `df_clean = df.copy()`. Then use `df_clean["Embarked"].fillna("Unknown")` to fill the missing `Embarked` values.
#
# <div style="border:2px solid #b45309; border-left:8px solid #b45309; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Your answer cell is directly below.</strong><br>
# This refresh check has no worked examples. Type your answer in the empty code cell under this orange box.
# </div>

# %% [markdown]
# ## Check 8 - Fill One Numeric Column
#
# Start with `df_clean = df.copy()`. Then use `df_clean["Age"].fillna(0)` to fill the missing `Age` values.
#
# <div style="border:2px solid #b45309; border-left:8px solid #b45309; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Your answer cell is directly below.</strong><br>
# This refresh check has no worked examples. Type your answer in the empty code cell under this orange box.
# </div>

# %% [markdown]
# ## Check 9 - Safe Cleaning Pattern
#
# Write the full safe-cleaning pattern: make `df_clean = df.copy()`, then remove only the rows where `Embarked` is missing by storing the cleaned result back into `df_clean`.
#
# <div style="border:2px solid #b45309; border-left:8px solid #b45309; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Your answer cell is directly below.</strong><br>
# This refresh check has no worked examples. Type your answer in the empty code cell under this orange box.
# </div>

# %% [markdown]
# ## Plain-English Findings
#
# Write three observations about what the missing-data checks or cleaning results showed.
#
# 1.
# 2.
# 3.
#
# Write one thing you would check before deciding whether to remove or fill missing values in a real project.
#
# -
#
# <div style="border:2px solid #b45309; border-left:8px solid #b45309; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Your answer cell is directly below.</strong><br>
# This refresh check has no worked examples. Type your answer in the empty code cell under this orange box.
# </div>
