# %% [markdown]
# # Block 8 Refresh Check - Full EDA Cycle
#
# **Lesson dataset:** Seattle Weather CSV
# **Dataset file:** `seattle_weather.csv`, supplied in the `datasets` folder with these materials.
#
# When you run this notebook on your own machine, set the path to wherever your copy of `seattle_weather.csv` is saved. If you keep the supplied folder layout, use `../../datasets/seattle_weather.csv`.
#
# Time cap: 45 minutes.
#
# This is a short refresher, not a taught walkthrough.
#
# **Refresh dataset:** Seattle Weather (`seattle_weather.csv`)
#
# Run a full mini-EDA cold using the moves from Blocks 1 through 5. The notebook is scratch space. The deliverable is the findings note at the end.

# %% [markdown]
# ## Check 1 - Setup
#
# Import pandas as `pd`, import `matplotlib.pyplot as plt`, store the Seattle Weather file path in `dataset_path`, and load the CSV into `df`.
#
# Use this path:
#
# `../../datasets/seattle_weather.csv`

# %% [markdown]
# ## Check 2 - First Look
#
# Check the dataset shape, column names, data types, and missingness.
#
# Then write one quoted sentence saying what the table appears to contain.

# %% [markdown]
# ## Check 3 - Filtering Question
#
# Ask and answer one filtering question using a clear condition on one or more columns.
#
# Then write one quoted sentence saying what you learned from that filtered view.

# %% [markdown]
# ## Check 4 - Grouping Or Sorting Question
#
# Ask and answer one grouping question or one sorting question.
#
# Then write one quoted sentence saying what that result shows.

# %% [markdown]
# ## Check 5 - Chart And Description
#
# Create one chart from the Seattle Weather data.
#
# Then write one quoted sentence describing what the chart shows.

# %% [markdown]
# ## Check 6 - Next Question And Limit
#
# Write two quoted sentences:
#
# 1. One sentence stating what you would check next. Name the column or columns and the move you would use.
# 2. One sentence stating what this dataset cannot confirm on its own.

# %% [markdown]
# ## Findings Note
#
# Answer each of the four questions below in plain English.
# Every observation must be traceable to something visible in the data.
# Vague findings do not count.
#
# Question 1 - What does this data contain?
# Write here: shape, column names, data types, and what each column appears to represent.
#
# Question 2 - What stands out?
# Write here: unusual values, category imbalance, skew, patterns, or anything that would prompt a follow-up question.
#
# Question 3 - What would you check next?
# Write here: specific further questions the data raises. Name the columns and the move you would use.
#
# Question 4 - What can you not conclude from this data alone?
# Write here: honest limits. What the dataset cannot confirm, what context is missing, and what assumptions would be needed to go further.
