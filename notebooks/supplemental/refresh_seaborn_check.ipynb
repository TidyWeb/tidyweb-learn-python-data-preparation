# %% [markdown]
# # Seaborn Refresh Check
#
# **Refresh dataset:** Titanic CSV
# **Dataset file:** `titanic.csv`, supplied in the `datasets` folder with these materials.
#
# When you run this notebook on your own machine, set the path to wherever your copy of `titanic.csv` is saved. If you keep the supplied folder layout, use `../../datasets/titanic.csv`.

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df = pd.read_csv('../../datasets/titanic.csv')

# %% [markdown]
# ## Question 1
#
# Produce a scatter plot with `Age` on the x axis, `Fare` on the y axis, and dots coloured by `Survived`. Add a title. Show it.

# %% [markdown]
# ## Question 2
#
# Produce a bar plot showing average `Fare` for each `Pclass`. Add a title. Show it.

# %% [markdown]
# ## Question 3
#
# Produce a histogram of the `Age` column with `kde=True`. Add a title. Show it.

# %% [markdown]
# ## Question 4
#
# Produce a box plot showing the distribution of `Fare` for each `Pclass`. Add a title. Show it.

# %% [markdown]
# ## Question 5
#
# Compute the correlation matrix for `Age`, `Fare`, `SibSp`, and `Parch`. Produce a heatmap with `annot=True` and `fmt=".2f"`. Add a title. Show it.

# %% [markdown]
# ## Findings
#
# Write three plain-English observations about what the Titanic data showed across the five charts.
