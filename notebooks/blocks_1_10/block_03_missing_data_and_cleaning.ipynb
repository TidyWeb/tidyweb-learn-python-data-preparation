# %% [markdown]
# # Block 3 - Missing Data And Cleaning
#
# This notebook teaches how to find missing values, decide what they mean, and clean data in a careful, reversible way.
#
# **Lesson dataset:** Dirty Data CSV
# **Dataset file:** `dirty_data.csv`, supplied in the `datasets` folder with these materials.
#
# When you run this notebook on your own machine, set the path to wherever your copy of `dirty_data.csv` is saved. If you keep the supplied folder layout, use `../../datasets/dirty_data.csv`.
#
# This notebook uses one real lesson dataset only: `dirty_data.csv`.
#
# This block does **not** use Iris as the lesson dataset. That is deliberate. `iris.csv` has no missing values, so it would be a poor fit for a notebook whose main job is to teach how to find and handle missing values.
#
# The worked examples use a tiny dummy shelf-stock table with missing values. Dummy data is not the lesson data. It only holds simple values so you can see what a cleaning operation does before you apply that operation to the lesson dataset.
#
# The notebook has two kinds of code cells:
#
# - Blue worked-example markers = demonstration code with visible output.
# - Orange answer markers = your empty answer cell is directly below.
#
# Each teaching concept follows this pattern: explanation, command panel, labelled code breakdown, worked dummy example with visible output, lesson question, empty learner cell.

# %% [markdown]
# ## Setup Cells
#
# These are setup cells, not learner answer tasks.
#
# They are pre-filled so the notebook can run cleanly from top to bottom. They do not use the four-part teaching pattern. Run them first.

# %%
import pandas as pd

# %%
dataset_path = "../../datasets/dirty_data.csv"

# %%
df = pd.read_csv(dataset_path)

# %% [markdown]
# ## Worked Example Setup Cell
#
# This cell prepares the neutral dummy table used in the worked examples.
#
# - `dummy_path` = the file path for the dummy CSV.
# - `dummy_df` = the dummy table loaded from that CSV.
#
# This is example setup only. It is not part of the learner task.

# %%
dummy_path = "../../datasets/dummy_shelf_stock_missing.csv"
dummy_df = pd.read_csv(dummy_path)

# %% [markdown]
# ## Concept 1 - Find Missing Cells With df.isnull()
#
# Missing data means a cell has no recorded value. pandas marks that empty slot with `NaN`. The first cleaning step is to find where missing values are.
#
# ### Command Panel
#
# ```python
# dummy_df.isnull()
# ```
#
# **Plain-English meaning**
# Check every cell in the table and return `True` where the value is missing and `False` where the value exists.
#
# **Code breakdown**
#
# - `dummy_df` = the dummy table used in the worked example.
# - `.` = reach into the table and use one of its built-in tools.
# - `isnull` = the tool that tests each cell for a missing value.
# - `()` = brackets used to call the tool.
# - `True` means the cell is missing and `False` means the cell has a value.
#
# <div style="border:2px solid #1d4ed8; border-left:8px solid #1d4ed8; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Worked example code cell is directly below.</strong><br>
# This blue-marked step is a demonstration. Read it and inspect the output before you answer the lesson question.
# </div>

# %%
dummy_df.isnull()
# Out:
#     item  shelf  count  price
# 0  False  False  False  False
# 1  False   True  False  False
# 2  False  False   True  False
# 3  False  False  False   True
# 4  False  False  False  False

# %% [markdown]
# **Question on the lesson dataset - Dirty Data**
#
# Use `df.isnull()` to show which cells in `dirty_data.csv` are missing.
#
# <div style="border:2px solid #b45309; border-left:8px solid #b45309; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Your answer cell is directly below.</strong><br>
# Type your answer in the empty code cell under this orange box.
# </div>

# %% [markdown]
# ## Concept 2 - Count Missing Values With df.isnull().sum()
#
# After you find the missing cells, the next question is how many are missing in each column. This line chains two steps together: first mark missing cells, then count them.
#
# ### Command Panel
#
# ```python
# dummy_df.isnull().sum()
# ```
#
# **Plain-English meaning**
# Count how many missing values appear in each column of the table.
#
# **Code breakdown**
#
# - `dummy_df` = the table variable.
# - `.isnull()` = mark missing cells as `True` and present cells as `False`.
# - `.` = pass the result of one step into the next step.
# - `.sum()` = add the `True` values column by column. `True` counts as 1 and `False` counts as 0.
# - `isnull().sum()` = a chain: find missing cells first, then count them.
#
# <div style="border:2px solid #1d4ed8; border-left:8px solid #1d4ed8; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Worked example code cell is directly below.</strong><br>
# This blue-marked step is a demonstration. Read it and inspect the output before you answer the lesson question.
# </div>

# %%
dummy_df.isnull().sum()
# Out:
# item     0
# shelf    1
# count    1
# price    1
# dtype: int64

# %% [markdown]
# **Question on the lesson dataset - Dirty Data**
#
# Use `df.isnull().sum()` to count the missing values in each column of `dirty_data.csv`.
#
# <div style="border:2px solid #b45309; border-left:8px solid #b45309; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Your answer cell is directly below.</strong><br>
# Type your answer in the empty code cell under this orange box.
# </div>

# %% [markdown]
# ## Concept 3 - Make A Safe Copy With df.copy()
#
# Before you change a table, make a separate working copy. That way the original table stays available if you need to compare, restart, or undo a cleaning choice.
#
# ### Command Panel
#
# ```python
# df_clean = dummy_df.copy()
# ```
#
# **Plain-English meaning**
# Create a separate copy of the table and store it under the name `df_clean`.
#
# **Code breakdown**
#
# - `df_clean` = the name for the new working copy.
# - `=` = store the result on the right under the name on the left.
# - `dummy_df` = the original dummy table.
# - `.copy()` = make a separate copy so later changes do not affect the original table.
# - `df_clean` and `dummy_df` are separate after this line runs.
#
# <div style="border:2px solid #1d4ed8; border-left:8px solid #1d4ed8; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Worked example code cell is directly below.</strong><br>
# This blue-marked step is a demonstration. Read it and inspect the output before you answer the lesson question.
# </div>

# %%
df_clean = dummy_df.copy()
df_clean
# Out:
#      item shelf  count  price
# 0   bagel    A1   12.0   0.80
# 1    roll   NaN   18.0   0.55
# 2  muffin    B2    NaN   1.20
# 3   scone    B2    9.0    NaN
# 4    wrap    A1    5.0   1.40

# %% [markdown]
# **Question on the lesson dataset - Dirty Data**
#
# Make a safe working copy of `df` called `df_clean`, then display `df_clean` to confirm the copy exists.
#
# <div style="border:2px solid #b45309; border-left:8px solid #b45309; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Your answer cell is directly below.</strong><br>
# Type your answer in the empty code cell under this orange box.
# </div>

# %% [markdown]
# ## Concept 4 - Remove Rows With Any Missing Value Using dropna()
#
# A broad cleaning step is to remove any row that contains at least one missing value anywhere in that row. This can be useful, but it can also remove more data than you intended.
#
# ### Command Panel
#
# ```python
# df_clean.dropna()
# ```
#
# **Plain-English meaning**
# Remove every row that contains at least one missing value.
#
# **Code breakdown**
#
# - `df_clean` = the working copy being cleaned.
# - `.` = reach into the table copy and use one of its tools.
# - `dropna` = the tool that removes rows with missing values.
# - `()` = brackets used to call the tool.
# - `without subset` = check every column in the row, not just one column.
#
# <div style="border:2px solid #1d4ed8; border-left:8px solid #1d4ed8; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Worked example code cell is directly below.</strong><br>
# This blue-marked step is a demonstration. Read it and inspect the output before you answer the lesson question.
# </div>

# %%
df_clean = dummy_df.copy()
df_clean.dropna()
# Out:
#     item shelf  count  price
# 0  bagel    A1   12.0    0.8
# 4   wrap    A1    5.0    1.4

# %% [markdown]
# **Question on the lesson dataset - Dirty Data**
#
# Start by making `df_clean = df.copy()`. Then use `df_clean.dropna()` to show the rows from `dirty_data.csv` that remain after removing any row with a missing value.
#
# <div style="border:2px solid #b45309; border-left:8px solid #b45309; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Your answer cell is directly below.</strong><br>
# Type your answer in the empty code cell under this orange box.
# </div>

# %% [markdown]
# ## Concept 5 - Remove Rows Missing One Named Column With dropna(subset=[...])
#
# Sometimes you only care whether one specific column is missing. The `subset=` argument lets you limit the check to the named column or columns instead of the whole row.
#
# ### Command Panel
#
# ```python
# df_clean.dropna(subset=["shelf"])
# ```
#
# **Plain-English meaning**
# Remove only the rows where the `shelf` column is missing.
#
# **Code breakdown**
#
# - `df_clean` = the working copy being cleaned.
# - `.dropna(...)` = the row-removal tool.
# - `subset=` = limit which columns are checked for missing values.
# - `["shelf"]` = a list naming the column to check.
# - `dropna(subset=[...])` = narrower than plain `dropna()` because it does not check every column.
#
# <div style="border:2px solid #1d4ed8; border-left:8px solid #1d4ed8; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Worked example code cell is directly below.</strong><br>
# This blue-marked step is a demonstration. Read it and inspect the output before you answer the lesson question.
# </div>

# %%
df_clean = dummy_df.copy()
df_clean.dropna(subset=["shelf"])
# Out:
#      item shelf  count  price
# 0   bagel    A1   12.0    0.8
# 2  muffin    B2    NaN    1.2
# 3   scone    B2    9.0    NaN
# 4    wrap    A1    5.0    1.4

# %% [markdown]
# **Question on the lesson dataset - Dirty Data**
#
# Start by making `df_clean = df.copy()`. Then use `df_clean.dropna(subset=["Date"])` to remove only the rows where the `Date` value is missing.
#
# <div style="border:2px solid #b45309; border-left:8px solid #b45309; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Your answer cell is directly below.</strong><br>
# Type your answer in the empty code cell under this orange box.
# </div>

# %% [markdown]
# ## Concept 6 - Fill Missing Values In One Column With df["column"].fillna(value)
#
# Instead of removing rows, you can replace missing values with something you choose. Filling one named column is often safer than filling the whole table because the replacement can match that column's meaning.
#
# ### Command Panel
#
# ```python
# df_clean["shelf"].fillna("Unknown")
# ```
#
# **Plain-English meaning**
# Replace missing values in the `shelf` column with the word `"Unknown"`.
#
# **Code breakdown**
#
# - `df_clean` = the working copy.
# - `["shelf"]` = select one column by name.
# - `.` = reach into that selected column and use one of its tools.
# - `fillna` = the tool that replaces missing values.
# - `("Unknown")` = the replacement value used where the column has `NaN`.
#
# <div style="border:2px solid #1d4ed8; border-left:8px solid #1d4ed8; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Worked example code cell is directly below.</strong><br>
# This blue-marked step is a demonstration. Read it and inspect the output before you answer the lesson question.
# </div>

# %%
df_clean = dummy_df.copy()
df_clean["shelf"].fillna("Unknown")
# Out:
# 0         A1
# 1    Unknown
# 2         B2
# 3         B2
# 4         A1
# Name: shelf, dtype: str

# %% [markdown]
# **Question on the lesson dataset - Dirty Data**
#
# Start by making `df_clean = df.copy()`. Then use `df_clean["Date"].fillna("Unknown date")` to fill the missing `Date` value in the working copy.
#
# <div style="border:2px solid #b45309; border-left:8px solid #b45309; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Your answer cell is directly below.</strong><br>
# Type your answer in the empty code cell under this orange box.
# </div>

# %% [markdown]
# ## Concept 7 - Fill Missing Values In A Numeric Column
#
# A fill value should match the kind of data in the column. Text columns often need a text fill value, while numeric columns often need a numeric fill value such as `0` or a summary value.
#
# ### Command Panel
#
# ```python
# df_clean["count"].fillna(0)
# ```
#
# **Plain-English meaning**
# Replace missing values in the numeric `count` column with `0`.
#
# **Code breakdown**
#
# - `df_clean` = the working copy.
# - `["count"]` = select the numeric column to clean.
# - `.fillna()` = the replacement tool.
# - `0` = the numeric replacement value.
# - `match the value type` = numeric columns usually need numeric replacements, not text.
#
# <div style="border:2px solid #1d4ed8; border-left:8px solid #1d4ed8; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Worked example code cell is directly below.</strong><br>
# This blue-marked step is a demonstration. Read it and inspect the output before you answer the lesson question.
# </div>

# %%
df_clean = dummy_df.copy()
df_clean["count"].fillna(0)
# Out:
# 0    12.0
# 1    18.0
# 2     0.0
# 3     9.0
# 4     5.0
# Name: count, dtype: float64

# %% [markdown]
# **Question on the lesson dataset - Dirty Data**
#
# Start by making `df_clean = df.copy()`. Then use `df_clean["Calories"].fillna(0)` to fill the missing calorie values in the working copy.
#
# <div style="border:2px solid #b45309; border-left:8px solid #b45309; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Your answer cell is directly below.</strong><br>
# Type your answer in the empty code cell under this orange box.
# </div>

# %% [markdown]
# ## Concept 8 - Safe Cleaning Pattern: Copy First, Then Clean
#
# The safest cleaning habit is a two-line pattern: first copy the original table, then clean the copy. That keeps the original table untouched while you test your cleaning decision.
#
# ### Command Panel
#
# ```python
# df_clean = df.copy()
# df_clean = df_clean.dropna(subset=["shelf"])
# ```
#
# **Plain-English meaning**
# Make a working copy, then clean the copy by removing rows where one named column is missing.
#
# **Code breakdown**
#
# - `df_clean = df.copy()` = create the separate working copy first.
# - `df_clean =` = store the cleaned result back into the working-copy name.
# - `df_clean.dropna(...)` = clean the working copy, not the original table.
# - `subset=["shelf"]` = say exactly which column controls the removal step.
# - `df` stays untouched while `df_clean` changes.
#
# <div style="border:2px solid #1d4ed8; border-left:8px solid #1d4ed8; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Worked example code cell is directly below.</strong><br>
# This blue-marked step is a demonstration. Read it and inspect the output before you answer the lesson question.
# </div>

# %%
df_clean = dummy_df.copy()
df_clean = df_clean.dropna(subset=["shelf"])
df_clean
# Out:
#      item shelf  count  price
# 0   bagel    A1   12.0    0.8
# 2  muffin    B2    NaN    1.2
# 3   scone    B2    9.0    NaN
# 4    wrap    A1    5.0    1.4

# %% [markdown]
# **Question on the lesson dataset - Dirty Data**
#
# Write the full safe-cleaning pattern on the lesson dataset: make `df_clean = df.copy()`, then remove only the rows where `Date` is missing by storing the cleaned result back into `df_clean`.
#
# <div style="border:2px solid #b45309; border-left:8px solid #b45309; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Your answer cell is directly below.</strong><br>
# Type your answer in the empty code cell under this orange box.
# </div>

# %% [markdown]
# ## Plain-English Findings
#
# After you finish the learner cells, write three observations about what the missing-data checks or cleaning results showed.
#
# These should be about the data, not about the commands.
#
# 1.
# 2.
# 3.
#
# Also write one thing you would check before deciding whether to remove or fill missing values in a real project.
#
# -
