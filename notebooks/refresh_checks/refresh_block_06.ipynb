# %% [markdown]
# # Block 6 Refresh Check - Titanic Statistics Foundations
#
# Time cap: 45 minutes.
#
# This is a short refresher, not a taught walkthrough.
#
# **Refresh dataset:** Titanic CSV
# **Dataset file:** `titanic.csv`, supplied in the `datasets` folder with these materials.
#
# When you run this notebook on your own machine, set the path to wherever your copy of `titanic.csv` is saved. If you keep the supplied folder layout, use `../../datasets/titanic.csv`.

# %% [markdown]
# ## Check 1 - Setup
#
# Import pandas as `pd`, import `matplotlib.pyplot as plt`, store the Titanic file path in `dataset_path`, and load the CSV into `df`.
#
# <div style="border:2px solid #b45309; border-left:8px solid #b45309; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Your answer cell is directly below.</strong><br>
# This orange-marked step is for your own answer. No worked example is provided in a refresh check.
# </div>

# %% [markdown]
# ## Check 2 - Mean
#
# Calculate the mean of the `Fare` column.
#
# <div style="border:2px solid #b45309; border-left:8px solid #b45309; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Your answer cell is directly below.</strong><br>
# This orange-marked step is for your own answer. No worked example is provided in a refresh check.
# </div>

# %% [markdown]
# ## Check 3 - Median
#
# Calculate the median of the `Age` column.
#
# <div style="border:2px solid #b45309; border-left:8px solid #b45309; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Your answer cell is directly below.</strong><br>
# This orange-marked step is for your own answer. No worked example is provided in a refresh check.
# </div>

# %% [markdown]
# ## Check 4 - Mode
#
# Calculate the mode of the `Embarked` column.
#
# <div style="border:2px solid #b45309; border-left:8px solid #b45309; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Your answer cell is directly below.</strong><br>
# This orange-marked step is for your own answer. No worked example is provided in a refresh check.
# </div>

# %% [markdown]
# ## Check 5 - Standard Deviation
#
# Calculate the standard deviation of the `Fare` column.
#
# <div style="border:2px solid #b45309; border-left:8px solid #b45309; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Your answer cell is directly below.</strong><br>
# This orange-marked step is for your own answer. No worked example is provided in a refresh check.
# </div>

# %% [markdown]
# ## Check 6 - Distribution Shape
#
# Create a histogram of the `Fare` column, then write one quoted sentence describing the shape of that distribution.
#
# <div style="border:2px solid #b45309; border-left:8px solid #b45309; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Your answer cell is directly below.</strong><br>
# This orange-marked step is for your own answer. No worked example is provided in a refresh check.
# </div>

# %% [markdown]
# ## Check 7 - Sample Vs Population
#
# Write one quoted sentence stating whether this Titanic table should be treated as a sample or a population, and why.
#
# <div style="border:2px solid #b45309; border-left:8px solid #b45309; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Your answer cell is directly below.</strong><br>
# This orange-marked step is for your own answer. No worked example is provided in a refresh check.
# </div>

# %% [markdown]
# ## Plain-English Findings
#
# Write three observations about what your Titanic summary statistics showed.
#
# 1.
# 2.
# 3.
#
# Write one thing these summary statistics do not tell on their own.
#
# -
#
# <div style="border:2px solid #b45309; border-left:8px solid #b45309; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Your answer cell is directly below.</strong><br>
# This orange-marked step is for your own answer. No worked example is provided in a refresh check.
# </div>
