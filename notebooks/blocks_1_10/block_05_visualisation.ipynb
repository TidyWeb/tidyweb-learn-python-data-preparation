# %% [markdown]
# # Block 5 - Visualisation With Seattle Weather
#
# This notebook teaches how to turn table data into charts that are quicker to scan, then say clearly what the chart shows and what it cannot show by itself.
#
# **Lesson dataset:** Seattle Weather CSV
# **Dataset file:** `seattle_weather.csv`, supplied in the `datasets` folder with these materials.
#
# When you run this notebook on your own machine, set the path to wherever your copy of `seattle_weather.csv` is saved. If you keep the supplied folder layout, use `../../datasets/seattle_weather.csv`.
#
# This notebook uses one real lesson dataset only: Seattle Weather. Every learner question in this notebook is about Seattle Weather.
#
# The worked examples use a separate neutral dummy table. Dummy data is not the lesson data. It only holds simple values so you can see what a charting move does before you apply that move to Seattle Weather.
#
# The notebook has two kinds of code cells:
#
# - Blue worked-example markers = demonstration code with visible output.
# - Orange answer markers = your empty answer cell is directly below.

# %% [markdown]
# ## Setup Cells
#
# These are setup cells, not learner answer tasks.
#
# They are pre-filled so the notebook can run cleanly from top to bottom. Run them first.

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
dataset_path = "../../datasets/seattle_weather.csv"

# %%
df = pd.read_csv(dataset_path)

# %%
dummy_path = "../../datasets/dummy_category_values.csv"
dummy_df = pd.read_csv(dummy_path)

# %% [markdown]
# ## Concept 1 - What A Chart Is And Why It Exists
#
# A chart helps the eye notice pattern, spread, imbalance, or relationship faster than a long printed table. A chart is not automatically an explanation. It is a view of the data from one angle.

# %% [markdown]
# ## Concept 2 - The Two Imports
#
# Pandas and matplotlib are two different Python libraries. Pandas helps us work with table data. Matplotlib helps us draw charts. The short nickname `pd` points to pandas. The short nickname `plt` points to matplotlib.pyplot. Both aliases need to be explained before either import line is shown.
#
#
# **Worked dummy example - confirm both aliases**
#
# ```python
# import pandas as pd
# import matplotlib.pyplot as plt
# print(pd.__name__)
# print(plt.__name__)
# ```
#
# <div style="border:2px solid #1d4ed8; border-left:8px solid #1d4ed8; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Worked example code cell is directly below.</strong><br>
# This blue-marked step is a demonstration. Read it and inspect the output before you answer the Seattle Weather question.
# </div>

# %%
import pandas as pd
import matplotlib.pyplot as plt
print(pd.__name__)
print(plt.__name__)
# Out:
# pandas
# matplotlib.pyplot

# %% [markdown]
# **Question on the lesson dataset - Seattle Weather**
#
# Copy both import lines exactly, then run `print(pd.__name__)` and `print(plt.__name__)` to confirm both aliases.
#
# <div style="border:2px solid #b45309; border-left:8px solid #b45309; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Your answer cell is directly below.</strong><br>
# Type your Seattle Weather answer in the empty code cell under this orange box.
# </div>

# %% [markdown]
# ## Concept 3 - Bar Chart
#
# A bar chart is useful when the question is about categories and counts or category totals. The bars make it easy to compare which category is larger or smaller.
#
#
# **Worked dummy example - category counts as bars**
#
# ```python
# dummy_df["category"].value_counts().plot(kind="bar")
# plt.show(block=False)
# ```
#
# <div style="border:2px solid #1d4ed8; border-left:8px solid #1d4ed8; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Worked example code cell is directly below.</strong><br>
# This blue-marked step is a demonstration. Read it and inspect the output before you answer the Seattle Weather question.
# </div>

# %%
dummy_df["category"].value_counts().plot(kind="bar")
plt.show(block=False)

# %% [markdown]
# **Question on the lesson dataset - Seattle Weather**
#
# Create a bar chart showing how often each `weather` label appears.
#
# <div style="border:2px solid #b45309; border-left:8px solid #b45309; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Your answer cell is directly below.</strong><br>
# Type your Seattle Weather answer in the empty code cell under this orange box.
# </div>

# %% [markdown]
# ## Concept 4 - Histogram
#
# A histogram is useful when the question is about spread or distribution in one numeric column. It helps you see where values cluster and whether the values stretch out or pile up.
#
#
# **Worked dummy example - one numeric column as a histogram**
#
# ```python
# dummy_df["value"].plot(kind="hist")
# plt.show(block=False)
# ```
#
# <div style="border:2px solid #1d4ed8; border-left:8px solid #1d4ed8; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Worked example code cell is directly below.</strong><br>
# This blue-marked step is a demonstration. Read it and inspect the output before you answer the Seattle Weather question.
# </div>

# %%
dummy_df["value"].plot(kind="hist")
plt.show(block=False)

# %% [markdown]
# **Question on the lesson dataset - Seattle Weather**
#
# Create a histogram for `temp_max`.
#
# <div style="border:2px solid #b45309; border-left:8px solid #b45309; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Your answer cell is directly below.</strong><br>
# Type your Seattle Weather answer in the empty code cell under this orange box.
# </div>

# %% [markdown]
# ## Concept 5 - Scatter Plot
#
# A scatter plot is useful when the question is about whether two numeric columns move together or apart. Each point represents one row placed by its x and y values.
#
#
# **Worked dummy example - two numeric columns as points**
#
# ```python
# dummy_df.plot.scatter(x="score", y="value")
# plt.show(block=False)
# ```
#
# <div style="border:2px solid #1d4ed8; border-left:8px solid #1d4ed8; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Worked example code cell is directly below.</strong><br>
# This blue-marked step is a demonstration. Read it and inspect the output before you answer the Seattle Weather question.
# </div>

# %%
dummy_df.plot.scatter(x="score", y="value")
plt.show(block=False)

# %% [markdown]
# **Question on the lesson dataset - Seattle Weather**
#
# Create a scatter plot with `temp_min` on the x axis and `temp_max` on the y axis.
#
# <div style="border:2px solid #b45309; border-left:8px solid #b45309; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Your answer cell is directly below.</strong><br>
# Type your Seattle Weather answer in the empty code cell under this orange box.
# </div>

# %% [markdown]
# ## Concept 6 - Chart Choice Rule
#
# Different chart types answer different kinds of questions. A bar chart fits category comparison. A histogram fits one numeric distribution. A scatter plot fits the relationship between two numeric columns.
#
#
# **Worked dummy example - bar chart chosen for a category question**
#
# ```python
# dummy_df["category"].value_counts().plot(kind="bar")
# plt.show(block=False)
# print("A bar chart fits this question because the data is categorical and we want to compare counts.")
# ```
#
# <div style="border:2px solid #1d4ed8; border-left:8px solid #1d4ed8; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Worked example code cell is directly below.</strong><br>
# This blue-marked step is a demonstration. Read it and inspect the output before you answer the Seattle Weather question.
# </div>

# %%
dummy_df["category"].value_counts().plot(kind="bar")
plt.show(block=False)
print("A bar chart fits this question because the data is categorical and we want to compare counts.")
# Out:
# A bar chart fits this question because the data is categorical and we want to compare counts.

# %% [markdown]
# **Question on the lesson dataset - Seattle Weather**
#
# Choose which of the three chart types best fits this question and state why: `How often does each weather label appear?`
#
# <div style="border:2px solid #b45309; border-left:8px solid #b45309; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Your answer cell is directly below.</strong><br>
# Type your Seattle Weather answer in the empty code cell under this orange box.
# </div>

# %% [markdown]
# ## Concept 7 - What A Chart Shows And What It Cannot Show
#
# A chart should be followed by two sentences: one saying what the chart shows, and one saying what it cannot show from that view alone. The chart is evidence, not the full explanation.
#
#
# **Worked dummy example - one show sentence and one limit sentence**
#
# ```python
# dummy_df["category"].value_counts().plot(kind="bar")
# plt.show(block=False)
# print("Shows: Category A appears most often in this dummy table.")
# print("Cannot show: This chart does not explain why Category A appears most often.")
# ```
#
# <div style="border:2px solid #1d4ed8; border-left:8px solid #1d4ed8; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Worked example code cell is directly below.</strong><br>
# This blue-marked step is a demonstration. Read it and inspect the output before you answer the Seattle Weather question.
# </div>

# %%
dummy_df["category"].value_counts().plot(kind="bar")
plt.show(block=False)
print("Shows: Category A appears most often in this dummy table.")
print("Cannot show: This chart does not explain why Category A appears most often.")
# Out:
# Shows: Category A appears most often in this dummy table.
# Cannot show: This chart does not explain why Category A appears most often.

# %% [markdown]
# **Question on the lesson dataset - Seattle Weather**
#
# For each chart you produced above, write one sentence saying what it shows and one sentence saying what it cannot show from that view alone.
#
# <div style="border:2px solid #b45309; border-left:8px solid #b45309; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Your answer cell is directly below.</strong><br>
# Type your Seattle Weather answer in the empty code cell under this orange box.
# </div>

# %% [markdown]
# ## Plain-English Findings
#
# Write three observations about what the Seattle Weather charts revealed.
#
# 1.
# 2.
# 3.
#
# Write one thing the charts do not explain on their own.
#
# -
