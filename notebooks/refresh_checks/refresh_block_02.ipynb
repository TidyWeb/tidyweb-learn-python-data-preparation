# %% [markdown]
# # Block 2 Refresh Check - Seattle Weather Filtering
#
# Time cap: 45 minutes.
#
# This is a short refresher of Block 2, not a taught walkthrough.
#
# **Refresh dataset:** Seattle Weather CSV
# **Dataset file:** `seattle_weather.csv`, supplied in the `datasets` folder with these materials.
#
# When you run this notebook on your own machine, set the path to wherever your copy of `seattle_weather.csv` is saved. If you keep the supplied folder layout, use `../../datasets/seattle_weather.csv`.
#
# Use this notebook to check whether the Block 2 selection and filtering moves transfer to a different dataset.
#
# No worked examples appear in this notebook. Every code cell is for your own answer.

# %% [markdown]
# ## Check 1 - Setup
#
# Import pandas as `pd`, store the Seattle Weather file path in `dataset_path`, and load the CSV into `df`.
#
# <div style="border:2px solid #b45309; border-left:8px solid #b45309; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Your answer cell is directly below.</strong><br>
# This refresh check has no worked examples. Type your answer in the empty code cell under this orange box.
# </div>

# %% [markdown]
# ## Check 2 - What Filtering Means
#
# Write a line that asks a yes-or-no question about each row: is the `weather` value equal to `"rain"`? Show the `True` and `False` results only.
#
# <div style="border:2px solid #b45309; border-left:8px solid #b45309; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Your answer cell is directly below.</strong><br>
# This refresh check has no worked examples. Type your answer in the empty code cell under this orange box.
# </div>

# %% [markdown]
# ## Check 3 - Equality Filter
#
# Keep only the rows where `weather` equals `"rain"`.
#
# <div style="border:2px solid #b45309; border-left:8px solid #b45309; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Your answer cell is directly below.</strong><br>
# This refresh check has no worked examples. Type your answer in the empty code cell under this orange box.
# </div>

# %% [markdown]
# ## Check 4 - Not-Equal Filter
#
# Keep only the rows where `weather` does not equal `"rain"`.
#
# <div style="border:2px solid #b45309; border-left:8px solid #b45309; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Your answer cell is directly below.</strong><br>
# This refresh check has no worked examples. Type your answer in the empty code cell under this orange box.
# </div>

# %% [markdown]
# ## Check 5 - Greater-Than Filter
#
# Keep only the rows where `temp_max` is greater than `20`.
#
# <div style="border:2px solid #b45309; border-left:8px solid #b45309; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Your answer cell is directly below.</strong><br>
# This refresh check has no worked examples. Type your answer in the empty code cell under this orange box.
# </div>

# %% [markdown]
# ## Check 6 - Less-Than Filter
#
# Keep only the rows where `wind` is less than `3`.
#
# <div style="border:2px solid #b45309; border-left:8px solid #b45309; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Your answer cell is directly below.</strong><br>
# This refresh check has no worked examples. Type your answer in the empty code cell under this orange box.
# </div>

# %% [markdown]
# ## Check 7 - Outer And Inner Brackets
#
# Use the full outer-and-inner bracket structure to keep only the rows where `weather` equals `"sun"`.
#
# <div style="border:2px solid #b45309; border-left:8px solid #b45309; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Your answer cell is directly below.</strong><br>
# This refresh check has no worked examples. Type your answer in the empty code cell under this orange box.
# </div>

# %% [markdown]
# ## Check 8 - Two-Condition AND Filter
#
# Keep only the rows where `weather` equals `"rain"` and `wind` is greater than `4`.
#
# <div style="border:2px solid #b45309; border-left:8px solid #b45309; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Your answer cell is directly below.</strong><br>
# This refresh check has no worked examples. Type your answer in the empty code cell under this orange box.
# </div>

# %% [markdown]
# ## Check 9 - Two-Condition OR Filter
#
# Keep the rows where `weather` equals `"snow"` or `temp_min` is less than `0`.
#
# <div style="border:2px solid #b45309; border-left:8px solid #b45309; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Your answer cell is directly below.</strong><br>
# This refresh check has no worked examples. Type your answer in the empty code cell under this orange box.
# </div>

# %% [markdown]
# ## Check 10 - Parentheses Rule
#
# Use parentheses correctly to keep only the rows where `weather` equals `"drizzle"` and `precipitation` is greater than `0`.
#
# <div style="border:2px solid #b45309; border-left:8px solid #b45309; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Your answer cell is directly below.</strong><br>
# This refresh check has no worked examples. Type your answer in the empty code cell under this orange box.
# </div>

# %% [markdown]
# ## Check 11 - Filtered Result Size
#
# Keep only the rows where `weather` equals `"sun"`, then use `.shape` to show the size of that filtered result.
#
# <div style="border:2px solid #b45309; border-left:8px solid #b45309; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Your answer cell is directly below.</strong><br>
# This refresh check has no worked examples. Type your answer in the empty code cell under this orange box.
# </div>

# %% [markdown]
# ## Plain-English Findings
#
# Write three observations about what your filtered Seattle Weather results showed.
#
# 1.
# 2.
# 3.
#
# Write one thing you would check next if this were a real analysis task.
#
# -
#
# <div style="border:2px solid #b45309; border-left:8px solid #b45309; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Your answer cell is directly below.</strong><br>
# This refresh check has no worked examples. Type your answer in the empty code cell under this orange box.
# </div>
