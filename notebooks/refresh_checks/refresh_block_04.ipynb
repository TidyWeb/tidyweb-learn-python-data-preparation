# %% [markdown]
# # Block 4 Refresh Check - Superstore Grouping And Insight
#
# Time cap: 45 minutes.
#
# This is a short refresher, not a taught walkthrough.
#
# **Refresh dataset:** Superstore Sales CSV
# **Dataset file:** `superstore_sales.csv`, supplied in the `datasets` folder with these materials.
#
# When you run this notebook on your own machine, set the path to wherever your copy of `superstore_sales.csv` is saved. If you keep the supplied folder layout, use `../../datasets/superstore_sales.csv`.

# %% [markdown]
# ## Check 1 - Setup
#
# Import pandas as `pd`, store the Superstore Sales file path in `dataset_path`, and load the CSV into `df`.
#
# <div style="border:2px solid #b45309; border-left:8px solid #b45309; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Your answer cell is directly below.</strong><br>
# This orange-marked step is for your own answer. No worked example is provided in a refresh check.
# </div>

# %% [markdown]
# ## Check 2 - Sort Rows
#
# Sort `df` by `Sales` from highest to lowest.
#
# <div style="border:2px solid #b45309; border-left:8px solid #b45309; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Your answer cell is directly below.</strong><br>
# This orange-marked step is for your own answer. No worked example is provided in a refresh check.
# </div>

# %% [markdown]
# ## Check 3 - Count Categories
#
# Count the values in the `Category` column with `.value_counts()`.
#
# <div style="border:2px solid #b45309; border-left:8px solid #b45309; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Your answer cell is directly below.</strong><br>
# This orange-marked step is for your own answer. No worked example is provided in a refresh check.
# </div>

# %% [markdown]
# ## Check 4 - Group And Average
#
# Group by `Category` and calculate the mean of `Sales`.
#
# <div style="border:2px solid #b45309; border-left:8px solid #b45309; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Your answer cell is directly below.</strong><br>
# This orange-marked step is for your own answer. No worked example is provided in a refresh check.
# </div>

# %% [markdown]
# ## Check 5 - Group And Count
#
# Group by `Category` and count the `Product Name` values.
#
# <div style="border:2px solid #b45309; border-left:8px solid #b45309; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Your answer cell is directly below.</strong><br>
# This orange-marked step is for your own answer. No worked example is provided in a refresh check.
# </div>

# %% [markdown]
# ## Check 6 - Several Group Summaries At Once
#
# Group by `Segment` and show the `Sales` mean, maximum, and minimum with `.agg(["mean", "max", "min"])`.
#
# <div style="border:2px solid #b45309; border-left:8px solid #b45309; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Your answer cell is directly below.</strong><br>
# This orange-marked step is for your own answer. No worked example is provided in a refresh check.
# </div>

# %% [markdown]
# ## Check 7 - Build A Grouped Result For Insight
#
# Create a grouped result that shows the mean `Profit` for each `Region`, then sort that grouped result from highest to lowest.
#
# <div style="border:2px solid #b45309; border-left:8px solid #b45309; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Your answer cell is directly below.</strong><br>
# This orange-marked step is for your own answer. No worked example is provided in a refresh check.
# </div>

# %% [markdown]
# ## Plain-English Findings
#
# Write three observations about what your grouped Superstore results showed.
#
# 1.
# 2.
# 3.
#
# Write one thing you would check next if this were a real analysis task.
#
# -
#
# <div style="border:2px solid #b45309; border-left:8px solid #b45309; padding:12px 14px; border-radius:8px; margin:10px 0;">
# <strong>Your answer cell is directly below.</strong><br>
# This orange-marked step is for your own answer. No worked example is provided in a refresh check.
# </div>
